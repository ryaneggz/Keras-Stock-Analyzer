# 17   2019-12-03  258.309998  259.529999  256.290009  259.450012  28607600.0
# 16   2019-12-04  261.070007  263.309998  260.679993  261.739990  16795400.0
# 15   2019-12-05  263.790009  265.890015  262.730011  265.579987  18606100.0
# 14   2019-12-06  267.480011  271.000000  267.299988  270.709991  26518900.0
# 13   2019-12-09  270.000000  270.799988  264.910004  266.920013  32010600.0
# 12   2019-12-10  268.600006  270.070007  265.859985  268.480011  22605100.0
# 11   2019-12-11  268.809998  271.100006  268.500000  270.769989  19689200.0
# 10   2019-12-12  267.779999  272.559998  267.320007  271.459991  34327600.0
# 9    2019-12-13  271.459991  275.299988  270.929993  275.149994  33396900.0
# 8    2019-12-16  277.000000  280.790009  276.980011  279.859985  32046500.0
# 7    2019-12-17  279.570007  281.769989  278.799988  280.410004  28539600.0
# 6    2019-12-18  279.799988  281.899994  279.119995  279.739990  29007100.0
# 5    2019-12-19  279.500000  281.179993  278.950012  280.019989  24592300.0
# 4    2019-12-20  282.230011  282.649994  278.559998  279.440002  68994500.0
# 3    2019-12-23  280.529999  284.250000  280.369995  284.000000  24643000.0
# 2    2019-12-24  284.690002  284.890015  282.920013  284.269989  12119700.0
# 1    2019-12-26  284.820007  289.980011  284.700012  289.910004  23280300.0
# 0    2019-12-27  291.119995  293.970001  288.119995  289.799988  36566500.0
#
#        adjclose
# 249  155.582367
# 248  140.085220
# 247  146.065353
# 246  145.740265
# 245  148.518509
# 244  151.040604
# 243  151.523376
# 242  150.035706
# 241  147.779602
# 240  150.804169
# 239  152.646484
# 238  153.552872
# 237  154.498657
# 236  151.030777
# 235  151.641586
# 234  150.439636
# 233  155.424744
# 232  153.986359
# 231  152.390320
# 230  162.803864
# 229  163.976242
# 228  164.055069
# 227  168.715042
# 226  171.601685
# 225  171.660797
# 224  168.409653
# 223  168.607529
# 222  167.637878
# 221  169.082443
# 220  168.379944
# ..          ...
# 29   262.640015
# 28   265.760010
# 27   267.100006
# 26   266.290009
# 25   263.190002
# 24   262.010010
# 23   261.779999
# 22   266.369995
# 21   264.290009
# 20   267.839996
# 19   267.250000
# 18   264.160004
# 17   259.450012
# 16   261.739990
# 15   265.579987
# 14   270.709991
# 13   266.920013
# 12   268.480011
# 11   270.769989
# 10   271.459991
# 9    275.149994
# 8    279.859985
# 7    280.410004
# 6    279.739990
# 5    280.019989
# 4    279.440002
# 3    284.000000
# 2    284.269989
# 1    289.910004
# 0    289.799988
#
# [250 rows x 7 columns]

# %%
training_data = data_training.drop(['date', 'adjclose'], axis = 1)
training_data.head()
# Out:
#           open      high       low     close       volume
# 9844  0.513393  0.515625  0.513393  0.513393  117258400.0
# 9843  0.488839  0.488839  0.486607  0.486607   43971200.0
# 9842  0.453125  0.453125  0.450893  0.450893   26432000.0
# 9841  0.462054  0.464286  0.462054  0.462054   21610400.0
# 9840  0.475446  0.477679  0.475446  0.475446   18362400.0

# %%
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data
# Out:
# array([[0.00136495, 0.00135878, 0.00138061, 0.00136697, 0.06302277],
#        [0.00125847, 0.00124395, 0.00126393, 0.00125145, 0.02351618],
#        [0.00110358, 0.00109085, 0.00110837, 0.00109743, 0.01406141],
#        ...,
#        [0.67499537, 0.67119837, 0.6528062 , 0.67258015, 0.02844642],
#        [0.68219458, 0.67870036, 0.67231978, 0.67292517, 0.02261066],
#        [0.68666155, 0.6823013 , 0.68072627, 0.67943738, 0.01868201]])

# %%
x_train = []
y_train = []

# %%
training_data.shape[0]
# Out:
# 9595

# %%
for i in range(60, training_data.shape[0]):
    x_train.append(training_data[i-60:i])
    y_train.append(training_data[i, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape, y_train.shape
# Out:
# ((9535, 60, 5), (9535,))

# %%
### Building LSTM

# %%
from keras import Sequential
from keras.layers import Dense, LSTM, Dropout
# Out:
# Using Theano backend.

# %%
regressior = Sequential()

regressior.add(LSTM(units = 60, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 5)))
regressior.add(Dropout(0.2))
               
regressior.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 120, activation = 'relu'))
regressior.add(Dropout(0.2))

regressior.add(Dense(units = 1))

# %%
regressior.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 60, 60)            15840
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 60)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 60)            29040
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 60)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 60, 80)            45120
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 80)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 120)               96480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 121
# =================================================================
# Total params: 186,601
# Trainable params: 186,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressior.compile(optimizer='sgd', metrics=['mae', 'acc'], loss = 'mean_squared_error')

# %%
regressior.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# C:\Users\reggl\Anaconda3\lib\site-packages\theano\scan_module\scan_perform_ext.py:76: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   "The file scan_perform.c is not available. This do"
# Epoch 1/10
# 9535/9535 [==============================] - 89s 9ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 2/10
# 9535/9535 [==============================] - 58s 6ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 3/10
# 9535/9535 [==============================] - 66s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 4/10
# 9535/9535 [==============================] - 64s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 5/10
# 9535/9535 [==============================] - 63s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 6/10
# 9535/9535 [==============================] - 64s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 7/10
# 9535/9535 [==============================] - 64s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 8/10
# 9535/9535 [==============================] - 64s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 9/10
# 9535/9535 [==============================] - 64s 7ms/step - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00
# Epoch 10/10
# 6432/9535 [===================>..........] - ETA: 20s - loss: nan - mean_absolute_error: nan - acc: 0.0000e+00

# %%
### Prepare test dataset

# %%
data_test.tail()

# %%
data_training.tail(60)

# %%
past_60_days = data_training.tail(60)

# %%
df = past_60_days.append(data_test, ignore_index = True)
df = df.drop(['date', 'adjclose'], axis = 1)
df.head()

# %%
inputs = scaler.transform(df)
inputs

# %%
x_test = []
y_test = []

for i in range(60, inputs.shape[0]):
    x_test.append(inputs[i-60:i])
    y_test.append(inputs[i, 0])

# %%
x_test, y_test = np.array(x_test),np.array(y_test)
x_test.shape, y_test.shape

# %%
y_pred = regressior.predict(x_test)

# %%
scaler.scale_

# %%
scale = 1/8.67066133e-03
scale

# %%
y_pred = y_pred*scale
y_test = y_test*scale

# %%
### Visualize Data

# %%
plt.figure(figsize=(20,5))
plt.plot(y_test, color = 'red', label = 'Real ' + str(stock_symbol) + ' stock price')
plt.plot(y_pred, color = 'blue', label = 'Predicted ' + str(stock_symbol) + ' stock price')
plt.title(str(stock_symbol) + ' Prediction Chart 2019')
plt.grid(color='y', linestyle='-', linewidth=1)
plt.xlabel('Time')
plt.ylabel(str(stock_symbol) + ' stock price')
plt.legend()
plt.show()
