# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('./csv/TSLA.timeseries.csv', date_parser = True)
data.tail()
# Out:
#             date       open   high        low      close    volume   adjclose
# 2387  2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001
# 2388  2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 2389  2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 2390  2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2391  2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999

# %%
data_training = data[data['date'] < '2019-01-01'].sort_values(by='date', ascending=True).copy()
data_training
# Out:
#             date        open        high         low       close    volume  \
# 2391  2010-06-29   19.000000   25.000000   17.540001   23.889999  18766300
# 2390  2010-06-30   25.790001   30.420000   23.299999   23.830000  17187100
# 2389  2010-07-01   25.000000   25.920000   20.270000   21.959999   8218800
# 2388  2010-07-02   23.000000   23.100000   18.709999   19.200001   5139800
# 2387  2010-07-06   20.000000   20.000000   15.830000   16.110001   6866900
# ...          ...         ...         ...         ...         ...       ...
# 254   2018-12-24  313.500000  314.500000  295.200012  295.390015   5559900
# 253   2018-12-26  300.000000  326.970001  294.089996  326.089996   8163100
# 252   2018-12-27  319.839996  322.170013  301.500000  316.130005   8575100
# 251   2018-12-28  323.100006  336.239990  318.410004  333.869995   9939000
# 250   2018-12-31  337.790009  339.209991  325.260010  332.799988   6302300
#
#         adjclose
# 2391   23.889999
# 2390   23.830000
# 2389   21.959999
# 2388   19.200001
# 2387   16.110001
# ...          ...
# 254   295.390015
# 253   326.089996
# 252   316.130005
# 251   333.869995
# 250   332.799988
#
# [2142 rows x 7 columns]

# %%
data_test = data[data['date'] >= '2019-01-01'].sort_values(by='date', ascending=True).copy()
data_test
# Out:
#            date        open        high         low       close    volume  \
# 249  2019-01-02  306.100006  315.130005  298.799988  310.119995  11658600
# 248  2019-01-03  307.000000  309.399994  297.380005  300.359985   6965200
# 247  2019-01-04  306.000000  318.000000  302.730011  317.690002   7394100
# 246  2019-01-07  321.720001  336.739990  317.750000  334.959991   7551200
# 245  2019-01-08  341.959991  344.010010  327.019989  335.350006   7008500
# ..          ...         ...         ...         ...         ...       ...
# 4    2019-12-20  410.290009  413.000000  400.190002  405.589996  14752700
# 3    2019-12-23  411.779999  422.010010  410.000000  419.220001  13319600
# 2    2019-12-24  418.359985  425.470001  412.690002  425.250000   8054700
# 1    2019-12-26  427.910004  433.480011  426.350006  430.940002  10633900
# 0    2019-12-27  435.000000  435.309998  426.109985  430.380005   9945700
#
#        adjclose
# 249  310.119995
# 248  300.359985
# 247  317.690002
# 246  334.959991
# 245  335.350006
# ..          ...
# 4    405.589996
# 3    419.220001
# 2    425.250000
# 1    430.940002
# 0    430.380005
#
# [250 rows x 7 columns]

# %%
training_data = data_training.drop(['date', 'adjclose'], axis = 1)
training_data.head()
# Out:
#            open   high        low      close    volume
# 2391  19.000000  25.00  17.540001  23.889999  18766300
# 2390  25.790001  30.42  23.299999  23.830000  17187100
# 2389  25.000000  25.92  20.270000  21.959999   8218800
# 2388  23.000000  23.10  18.709999  19.200001   5139800
# 2387  20.000000  20.00  15.830000  16.110001   6866900

# %%
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data
# Out:
# array([[0.00771826, 0.02244088, 0.00702583, 0.02191224, 0.50337694],
#        [0.02604237, 0.0369725 , 0.02283393, 0.02174973, 0.46074816],
#        [0.0239104 , 0.02490751, 0.01451821, 0.01668472, 0.21865873],
#        ...,
#        [0.81959248, 0.81918608, 0.78634354, 0.81346155, 0.22827666],
#        [0.82839024, 0.85690923, 0.83275242, 0.86151136, 0.26509364],
#        [0.86803402, 0.86487212, 0.85155201, 0.85861318, 0.16692491]])

# %%
x_train = []
y_train = []

# %%
training_data.shape[0]
# Out:
# 2142

# %%
for i in range(60, training_data.shape[0]):
    x_train.append(training_data[i-60:i])
    y_train.append(training_data[i, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape, y_train.shape
# Out:
# ((2082, 60, 5), (2082,))

# %%
### Building LSTM

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
regressior = Sequential()

regressior.add(LSTM(units = 60, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 5)))
regressior.add(Dropout(0.2))
               
regressior.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 120, activation = 'relu'))
regressior.add(Dropout(0.2))

regressior.add(Dense(units = 1))

# %%
regressior.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# unified_lstm (UnifiedLSTM)   (None, 60, 60)            15840
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 60)            0
# _________________________________________________________________
# unified_lstm_1 (UnifiedLSTM) (None, 60, 60)            29040
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 60)            0
# _________________________________________________________________
# unified_lstm_2 (UnifiedLSTM) (None, 60, 80)            45120
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 80)            0
# _________________________________________________________________
# unified_lstm_3 (UnifiedLSTM) (None, 120)               96480
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 121
# =================================================================
# Total params: 186,601
# Trainable params: 186,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressior.compile(optimizer='sgd', metrics=['accuracy'], loss = 'mean_squared_error')

# %%
regressior.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 2082/2082 [==============================] - 37s 18ms/sample - loss: 0.2416 - accuracy: 0.0000e+00
# Epoch 2/10
# 2082/2082 [==============================] - 30s 15ms/sample - loss: 0.1823 - accuracy: 0.0000e+00
# Epoch 3/10
# 2082/2082 [==============================] - 31s 15ms/sample - loss: 0.1452 - accuracy: 0.0000e+00
# Epoch 4/10
# 2082/2082 [==============================] - 26s 13ms/sample - loss: 0.1219 - accuracy: 0.0000e+00
# Epoch 5/10
# 2082/2082 [==============================] - 25s 12ms/sample - loss: 0.1085 - accuracy: 0.0000e+00
# Epoch 6/10
# 2082/2082 [==============================] - 28s 13ms/sample - loss: 0.0999 - accuracy: 0.0000e+00
# Epoch 7/10
# 2082/2082 [==============================] - 31s 15ms/sample - loss: 0.0952 - accuracy: 0.0000e+00
# Epoch 8/10
# 2082/2082 [==============================] - 30s 14ms/sample - loss: 0.0914 - accuracy: 0.0000e+00
# Epoch 9/10
# 2082/2082 [==============================] - 29s 14ms/sample - loss: 0.0898 - accuracy: 0.0000e+00
# Epoch 10/10
# 2082/2082 [==============================] - 30s 14ms/sample - loss: 0.0886 - accuracy: 0.0000e+00

# %%
### Prepare test dataset

# %%
data_test.tail()
# Out:
#          date        open        high         low       close    volume  \
# 4  2019-12-20  410.290009  413.000000  400.190002  405.589996  14752700
# 3  2019-12-23  411.779999  422.010010  410.000000  419.220001  13319600
# 2  2019-12-24  418.359985  425.470001  412.690002  425.250000   8054700
# 1  2019-12-26  427.910004  433.480011  426.350006  430.940002  10633900
# 0  2019-12-27  435.000000  435.309998  426.109985  430.380005   9945700
#
#      adjclose
# 4  405.589996
# 3  419.220001
# 2  425.250000
# 1  430.940002
# 0  430.380005

# %%
data_training.tail(60)
# Out:
#            date        open        high         low       close    volume  \
# 309  2018-10-04  293.950012  294.000000  277.670013  281.829987   9814200
# 308  2018-10-05  274.649994  274.880005  260.000000  261.950012  17944500
# 307  2018-10-08  264.519989  267.760010  249.000000  250.559998  13472700
# 306  2018-10-09  255.250000  266.769989  253.300003  262.799988  12060600
# 305  2018-10-10  264.609985  265.510010  247.770004  256.880005  12815300
# 304  2018-10-11  257.529999  262.250000  249.029999  252.229996   8167700
# 303  2018-10-12  261.000000  261.989990  252.009995  258.779999   7201400
# 302  2018-10-15  259.059998  263.279999  254.539993  259.589996   6200000
# 301  2018-10-16  265.700012  277.380005  262.239990  276.589996   9526400
# 300  2018-10-17  282.399994  282.700012  265.799988  271.779999   8655500
# 299  2018-10-18  269.290009  271.000000  263.000000  263.910004   5421200
# 298  2018-10-19  267.390015  269.660004  253.500000  260.000000   9375500
# 297  2018-10-22  260.679993  261.859985  252.589996  260.950012   5600300
# 296  2018-10-23  263.869995  297.929993  262.100006  294.140015  19027800
# 295  2018-10-24  301.049988  304.440002  285.730011  288.500000  20058300
# 294  2018-10-25  317.220001  321.000000  301.010010  314.859985  20840700
# 293  2018-10-26  308.250000  339.899994  306.649994  330.899994  27425500
# 292  2018-10-29  337.470001  347.160004  326.500000  334.850006  14486000
# 291  2018-10-30  328.390015  337.899994  322.260010  329.899994   9126700
# 290  2018-10-31  332.540009  342.000000  329.100006  337.320007   7624300
# 289  2018-11-01  338.260010  347.839996  334.730011  344.279999   8000100
# 288  2018-11-02  343.739990  349.200012  340.910004  346.410004   7808000
# 287  2018-11-05  340.500000  343.959991  330.140015  341.399994   7831000
# 286  2018-11-06  339.070007  348.799988  336.089996  341.059998   6762900
# 285  2018-11-07  343.339996  351.179993  340.799988  348.160004   7374500
# 284  2018-11-08  348.500000  357.579987  348.440002  351.399994   7090700
# 283  2018-11-09  349.000000  354.000000  345.230011  350.510010   5098800
# 282  2018-11-12  348.369995  349.779999  330.339996  331.279999   6941500
# 281  2018-11-13  333.160004  344.700012  332.200012  338.730011   5448600
# 280  2018-11-14  342.700012  347.109985  337.149994  344.000000   5040300
# 279  2018-11-15  342.329987  348.579987  339.040009  348.440002   4625700
# 278  2018-11-16  345.190002  355.700012  345.119995  354.309998   7206200
# 277  2018-11-19  356.339996  366.750000  352.880005  353.470001   9708900
# 276  2018-11-20  341.750000  349.799988  333.549988  347.489990   8004700
# 275  2018-11-21  352.000000  353.100006  337.399994  338.190002   4686800
# 274  2018-11-23  334.350006  337.500000  325.549988  325.829987   4202600
# 273  2018-11-26  325.000000  346.220001  325.000000  346.000000   7992100
# 272  2018-11-27  340.049988  346.959991  335.500000  343.920013   6358300
# 271  2018-11-28  345.989990  348.279999  342.209991  347.869995   4127600
# 270  2018-11-29  347.000000  347.500000  339.549988  341.170013   3080700
# 269  2018-11-30  341.829987  351.600006  338.260010  350.480011   5629100
# 268  2018-12-03  360.000000  366.000000  352.000000  358.489990   8306500
# 267  2018-12-04  356.049988  368.679993  352.000000  359.700012   8461900
# 266  2018-12-06  356.010010  367.380005  350.760010  363.059998   7842500
# 265  2018-12-07  369.000000  379.489990  357.649994  357.970001  11511200
# 264  2018-12-10  360.000000  365.980011  353.119995  365.149994   6613500
# 263  2018-12-11  369.910004  372.170013  360.230011  366.760010   6308800
# 262  2018-12-12  369.420013  371.910004  365.160004  366.600006   5027000
# 261  2018-12-13  370.149994  377.440002  366.750000  376.790009   7365900
# 260  2018-12-14  375.000000  377.869995  364.329987  365.709991   6337600
# 259  2018-12-17  362.000000  365.700012  343.880005  348.420013   7674000
# 258  2018-12-18  350.540009  351.549988  333.690002  337.029999   7100000
# 257  2018-12-19  337.600006  347.010010  329.739990  332.970001   8274200
# 256  2018-12-20  327.049988  330.290009  311.869995  315.380005   9071900
# 255  2018-12-21  317.399994  323.470001  312.440002  319.769989   8016800
# 254  2018-12-24  313.500000  314.500000  295.200012  295.390015   5559900
# 253  2018-12-26  300.000000  326.970001  294.089996  326.089996   8163100
# 252  2018-12-27  319.839996  322.170013  301.500000  316.130005   8575100
# 251  2018-12-28  323.100006  336.239990  318.410004  333.869995   9939000
# 250  2018-12-31  337.790009  339.209991  325.260010  332.799988   6302300
#
#        adjclose
# 309  281.829987
# 308  261.950012
# 307  250.559998
# 306  262.799988
# 305  256.880005
# 304  252.229996
# 303  258.779999
# 302  259.589996
# 301  276.589996
# 300  271.779999
# 299  263.910004
# 298  260.000000
# 297  260.950012
# 296  294.140015
# 295  288.500000
# 294  314.859985
# 293  330.899994
# 292  334.850006
# 291  329.899994
# 290  337.320007
# 289  344.279999
# 288  346.410004
# 287  341.399994
# 286  341.059998
# 285  348.160004
# 284  351.399994
# 283  350.510010
# 282  331.279999
# 281  338.730011
# 280  344.000000
# 279  348.440002
# 278  354.309998
# 277  353.470001
# 276  347.489990
# 275  338.190002
# 274  325.829987
# 273  346.000000
# 272  343.920013
# 271  347.869995
# 270  341.170013
# 269  350.480011
# 268  358.489990
# 267  359.700012
# 266  363.059998
# 265  357.970001
# 264  365.149994
# 263  366.760010
# 262  366.600006
# 261  376.790009
# 260  365.709991
# 259  348.420013
# 258  337.029999
# 257  332.970001
# 256  315.380005
# 255  319.769989
# 254  295.390015
# 253  326.089996
# 252  316.130005
# 251  333.869995
# 250  332.799988

# %%
past_60_days = data_training.tail(60)

# %%
df = past_60_days.append(data_test, ignore_index = True)
df = df.drop(['date', 'adjclose'], axis = 1)
df.head()
# Out:
#          open        high         low       close    volume
# 0  293.950012  294.000000  277.670013  281.829987   9814200
# 1  274.649994  274.880005  260.000000  261.950012  17944500
# 2  264.519989  267.760010  249.000000  250.559998  13472700
# 3  255.250000  266.769989  253.300003  262.799988  12060600
# 4  264.609985  265.510010  247.770004  256.880005  12815300

# %%
inputs = scaler.transform(df)
inputs
# Out:
# array([[0.74972341, 0.74365921, 0.72094302, 0.72055793, 0.2617248 ],
#        [0.69763862, 0.69239642, 0.67244832, 0.66671184, 0.48119335],
#        [0.67030087, 0.67330693, 0.64225923, 0.63586131, 0.360482  ],
#        ...,
#        [1.0854675 , 1.09614461, 1.09150039, 1.1090195 , 0.21422903],
#        [1.11124005, 1.11762032, 1.12898976, 1.12443121, 0.28385171],
#        [1.13037376, 1.12252671, 1.12833103, 1.12291442, 0.2652745 ]])

# %%
x_test = []
y_test = []

for i in range(60, inputs.shape[0]):
    x_test.append(inputs[i-60:i])
    y_test.append(inputs[i, 0])

# %%
x_test, y_test = np.array(x_test),np.array(y_test)
x_test.shape, y_test.shape
# Out:
# ((250, 60, 5), (250,))

# %%
y_pred = regressior.predict(x_test)

# %%
scaler.scale_
# Out:
# array([2.69869111e-03, 2.68110901e-03, 2.74446300e-03, 2.70855905e-03,
#        2.69939048e-08])

# %%
scale = 1/2.69869111e-03
scale
# Out:
# 370.55000340516926

# %%
y_pred = y_pred*scale
y_test = y_test*scale

# %%
### Visualize Data

# %%
plt.figure(figsize=(14,5))
plt.plot(y_test, color = 'red', label = 'Real IBM stock price')
plt.plot(y_pred, color = 'blue', label = 'Predicted IBM stock price')
plt.plot('IBM stock price prediction')
plt.xlabel('Time')
plt.ylabel('IBM stock price')
plt.legend()
plt.show()
